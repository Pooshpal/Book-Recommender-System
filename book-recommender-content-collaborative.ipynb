# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# /kaggle/input/book-recommendation-dataset/Ratings.csv
# /kaggle/input/book-recommendation-dataset/Users.csv
# /kaggle/input/book-recommendation-dataset/Books.csv

# %%
df1 = pd.read_csv('/kaggle/input/book-recommendation-dataset/Ratings.csv', low_memory=False)
df2 = pd.read_csv('/kaggle/input/book-recommendation-dataset/Users.csv', low_memory=False)
df3 = pd.read_csv('/kaggle/input/book-recommendation-dataset/Books.csv', low_memory=False)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271359 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
# remove 'DK Publishing Inc', 'Gallimard' values from 'Year-Of-Publication' column and convert to int
df3 = df3[~df3['Year-Of-Publication'].isin(['DK Publishing Inc', 'Gallimard'])]
df3['Year-Of-Publication'] = pd.to_numeric(df3['Year-Of-Publication'])

# %% [markdown]
# * Dataset 1 - Rating.csv (11149780)
#     * User-ID - user ID
#     * ISBN - book ID
#     * Book-Rating - Rating given by user
#
# * Dataset 2 - Users.csv (278858)
#     * User-ID - user ID
#     * Location - location of user
#     * Age - age of user
#
# * Dataset 3 - Books.csv (271360)
#     * ISBN - book ID
#     * Book-Title - Book Name
#     * Book-Author
#     * Year-Of-Publication
#     * Publisher
#     * Image-URL-S
#     * Image-URL-M
#     * Image-URL-L

# %% [markdown]
# # EDA

# %%
def plot_distribution(feature, data):
    sns.displot(x=feature, data=data, kde=True, color='#244747');
    plt.figtext(0.2, 1, '%s Distribution'%feature, fontfamily='serif', fontsize=17, fontweight='bold');

# %%
df2 = df2[df2['Age']<=120]
# Distribution of user as per age
plot_distribution('Age', df2)

# %% [markdown]
# remove users with age above 120

# %%
df3 = df3[(df3['Year-Of-Publication']>1950) & (df3['Year-Of-Publication']<=2016)]
# Distribution across year of publication
plot_distribution('Year-Of-Publication', df3)

# %% [markdown]
# remove books before 1950 as there are not many and before 2016

# %% [markdown]
# # Recommendor 1 : Demographic Filtering

# %% [markdown]
# ## 1. Top 20 Highest Rated Books

# %%
data = df1.groupby('ISBN').agg(['mean', 'count'])['Book-Rating'].reset_index()

# generate score based on mean rating and total number of times the book is rated
m = data['count'].quantile(0.99) # minimum votes required to be listed in the Top 250
data = data[data['count']>m]
print('m =', m)
print(data.shape)
R = data['mean'] # average for the book (mean) = (Rating)
v = data['count'] # number of votes for the book = (votes)
C = data['mean'].mean() # mean vote across all books
data['weighted rating'] = (v/(v+m))*R + (m/(v+m))*C
data = data.sort_values('weighted rating', ascending=False).reset_index(drop=True)

# get title of books
data = pd.merge(data, df3, on='ISBN')[['Book-Title', 'Book-Author', 'mean', 'count', 'weighted rating', 
                              'Year-Of-Publication']].drop_duplicates('Book-Title').iloc[:20]
data
# Out:
# m = 36.0
# (3306, 3)
#                                            Book-Title  \
# 0        Harry Potter and the Goblet of Fire (Book 4)
# 1    Harry Potter and the Chamber of Secrets (Book 2)
# 2                                                Free
# 3   Harry Potter and the Prisoner of Azkaban (Book 3)
# 4      Harry Potter and the Sorcerer's Stone (Book 1)
# 5   Harry Potter and the Order of the Phoenix (Boo...
# 6   The Fellowship of the Ring (The Lord of the Ri...
# 7   Griffin &amp; Sabine: An Extraordinary Corresp...
# 9                                          Falling Up
# 10         The Stand (The Complete and Uncut Edition)
# 11      Ender's Game (Ender Wiggins Saga (Paperback))
# 12                                  The Little Prince
# 13                            The Secret Life of Bees
# 14  Harry Potter and the Sorcerer's Stone (Harry P...
# 15  The Hobbit : The Enchanting Prelude to The Lor...
# 17                              To Kill a Mockingbird
# 18     The Two Towers (The Lord of the Rings, Part 2)
# 19                              The Horse and His Boy
# 20                    The Perks of Being a Wallflower
# 21                                 The Cat in the Hat
#
#                   Book-Author      mean  count  weighted rating  \
# 0               J. K. Rowling  6.541237    194         5.985285
# 1               J. K. Rowling  6.611765    170         5.978717
# 2                Paul Vincent  7.962963     54         5.973507
# 3               J. K. Rowling  6.467005    197         5.929681
# 4               J. K. Rowling  6.363095    168         5.767724
# 5               J. K. Rowling  5.571856    334         5.320583
# 6            J. R. R. Tolkien  6.206349     63         5.036522
# 7                Nick Bantock  6.041667     72         5.024219
# 9            Shel Silverstein  6.921053     38         5.008320
# 10               Stephen King  6.175439     57         4.942104
# 11           Orson Scott Card  5.302564    195         4.942059
# 12  Antoine de Saint-Exup̩ry  5.797468     79         4.918397
# 13              Sue Monk Kidd  5.500000     96         4.815270
# 14              J. K. Rowling  4.900175    571         4.786846
# 15             J.R.R. TOLKIEN  5.007117    281         4.777967
# 17                 Harper Lee  4.920308    389         4.756743
# 18           J. R. R. Tolkien  6.230769     39         4.674876
# 19                C. S. Lewis  6.216216     37         4.624872
# 20            Stephen Chbosky  5.194175    103         4.623134
# 21                  Dr. Seuss  5.730769     52         4.609269
#
#     Year-Of-Publication
# 0                  2000
# 1                  1999
# 2                  2003
# 3                  1999
# 4                  1998
# 5                  2003
# 6                  1999
# 7                  1991
# 9                  1996
# 10                 1990
# 11                 1994
# 12                 1968
# 13                 2002
# 14                 1999
# 15                 1986
# 17                 1988
# 18                 1999
# 19                 1994
# 20                 1999
# 21                 1957

# %% [markdown]
# ## 2. Top 20 Highest Rated Authors

# %%
# drop any duplicates in df3
df3 = df3.drop_duplicates(['Book-Author', 'Book-Title'])

# get book-author and title from df3
data = pd.merge(df3, df1, on='ISBN')[['Book-Author', 'Book-Rating', 'Book-Title', 'ISBN']]

data = data.groupby('Book-Author').agg(['mean', 'count'])['Book-Rating'].reset_index()

# generate score based on mean rating and total number of times the author is rated
m = data['count'].quantile(0.99) # minimum votes required to be listed in the Top 250
data = data[data['count']>m]
print('m =', m)
print(data.shape)
R = data['mean'] # average for the author (mean) = (Rating)
v = data['count'] # number of votes for the author = (votes)
C = data['mean'].mean() # mean vote across all authors
data['weighted rating'] = (v/(v+m))*R + (m/(v+m))*C
data = data.sort_values('weighted rating', ascending=False).reset_index(drop=True)

data.iloc[:20]
# Out:
# m = 130.0
# (996, 3)
#                   Book-Author      mean  count  weighted rating
# 0               J. K. Rowling  5.411434   2134         5.263202
# 1              Bill Watterson  5.498134    536         4.977312
# 2            J. R. R. Tolkien  5.265861    662         4.866023
# 3            Shel Silverstein  6.273333    150         4.674607
# 4                   Dr. Seuss  5.168044    363         4.551501
# 5                Nick Bantock  5.278810    269         4.480927
# 6                  Harper Lee  4.932039    412         4.427841
# 7              J.R.R. TOLKIEN  4.511224    980         4.314315
# 8                 Neil Gaiman  4.453074   1236         4.298602
# 9                Daniel Quinn  5.012295    244         4.253716
# 10              George Orwell  4.568862    501         4.210602
# 11  Antoine de Saint-Exup̩ry  5.169492    177         4.178795
# 12                Gary Larson  4.470389    591         4.174605
# 13                Mitch Albom  4.474820    556         4.163105
# 14              J.D. Salinger  4.487713    529         4.160683
# 15                      Herge  5.351724    145         4.159600
# 16             J.R.R. Tolkien  4.818533    259         4.153959
# 17               Alice Sebold  4.212054   1792         4.118569
# 18                C. S. Lewis  4.281381    956         4.107633
# 19                 LOIS LOWRY  4.638710    310         4.104295

# %% [markdown]
# # Recommender 2: Collaborative Filtering
# Based on records from various users provide recommendations based on user similarities

# %%
# merge df1 and df5 to get movie titles and drop rows for which title is not available
data = pd.merge(df1, df3, on='ISBN')

# get total counts of no. of occurence of book
data['count'] = data.groupby('ISBN').transform('count')['User-ID']

# fetch top 100 books based on count
isbn = data.drop_duplicates('ISBN').sort_values(
    'count', ascending=False).iloc[:100]['ISBN']

# filter out data as per the ISBN
data = data[data['ISBN'].isin(isbn)].reset_index(drop=True)

# %%
# create a user book rating matrix
df = data.pivot(index='User-ID', columns='ISBN', values='Book-Rating')
df.head()
# Out:
# ISBN     0060392452  0060502258  0060928336  0060930535  0060934417  \
# User-ID
# 9               NaN         NaN         NaN         NaN         NaN
# 14              NaN         NaN         NaN         NaN         NaN
# 16              NaN         NaN         NaN         NaN         NaN
# 26              NaN         NaN         NaN         NaN         NaN
# 51              NaN         NaN         NaN         NaN         NaN
#
# ISBN     0060938455  0060959037  0060976845  0060987103  0061009059  ...  \
# User-ID                                                              ...
# 9               NaN         NaN         NaN         NaN         NaN  ...
# 14              NaN         NaN         NaN         NaN         NaN  ...
# 16              NaN         NaN         NaN         NaN         NaN  ...
# 26              NaN         NaN         NaN         NaN         NaN  ...
# 51              NaN         NaN         NaN         NaN         NaN  ...
#
# ISBN     0743237188  0743418174  0786868716  080410526X  0804106304  \
# User-ID
# 9               NaN         NaN         NaN         NaN         NaN
# 14              NaN         NaN         NaN         NaN         NaN
# 16              NaN         NaN         NaN         NaN         NaN
# 26              NaN         NaN         NaN         NaN         NaN
# 51              NaN         NaN         NaN         NaN         NaN
#
# ISBN     0805063897  0842329129  0971880107  1400034779  1558743669
# User-ID
# 9               NaN         NaN         NaN         NaN         NaN
# 14              NaN         NaN         0.0         NaN         NaN
# 16              NaN         NaN         NaN         NaN         NaN
# 26              NaN         NaN         NaN         NaN         NaN
# 51              NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 100 columns]

# %%
# get user-ID for users who have read more than 50 books
temp = df[~df.isna()].count(axis=1).reset_index()
temp[temp[0]>50]
# Out:
#        User-ID    0
# 629      11676  100
# 912      16795   70
# 1158     21014   54
# 1323     23768   54
# 2131     35859   69
# 2647     43246   54
# 3682     60244   53
# 4628     76352   54
# 4769     78783   51
# 6170    102967   54
# 6336    105979   52
# 6349    106225   52
# 13716   230522   61
# 13824   232131   53
# 14186   238120   58

# %% [markdown]
# ## 1. Using Surpise Library

# %%
from surprise import Reader, Dataset, SVD
from surprise.model_selection import train_test_split, cross_validate

# %%
reader = Reader(rating_scale=(0, 10))
surprise_data = Dataset.load_from_df(data[['User-ID', 'ISBN', 'Book-Rating']], reader)
trainset, testset = train_test_split(surprise_data, test_size=0.25)

# %%
benchmark = []
# Iterate over all algorithms
for algorithm in [SVD()]:
    # Perform cross validation
    results = cross_validate(algorithm, surprise_data, measures=['RMSE'], cv=3, verbose=False)
    
    # Get results & append algorithm name
    tmp = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    benchmark.append(tmp)
    
pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')
# Out:
#            test_rmse  fit_time  test_time
# Algorithm
# SVD         3.906093  2.848762   0.146185

# %%
svd = SVD() 
svd.fit(trainset)

# %%
index_val = 2131
# get user id
userId = df.index[index_val]
books = []
ratings = []
titles = []

for isbn in df.iloc[index_val][df.iloc[index_val].isna()].index:
    books.append(isbn)
    title = data[data['ISBN']==isbn]['Book-Title'].values[0]
    titles.append(title)
    ratings.append(svd.predict(userId, isbn).est)

prediction = pd.DataFrame({'ISBN':books, 'title':titles, 'rating':ratings, 'userId':userId})  
prediction = prediction.sort_values('rating', ascending=False).iloc[:10].reset_index(drop=True)

# get other high rated books by user
temp = data[data['User-ID']==df.index[index_val]].sort_values(
    'Book-Rating', ascending=False)[['Book-Rating', 'Book-Title', 'User-ID']].iloc[:10].reset_index(drop=True)
prediction['Book Read'] = temp['Book-Title']
prediction['Rated']= temp['Book-Rating']
prediction
# Out:
#          ISBN                                              title    rating  \
# 0  0140293248            The Girls' Guide to Hunting and Fishing  5.665600
# 1  0446612545                                    The Beach House  4.906809
# 2  0060959037                           Prodigal Summer: A Novel  4.630792
# 3  0440206154                                         Red Dragon  4.475506
# 4  0345339703  The Fellowship of the Ring (The Lord of the Ri...  3.652609
# 5  0060987103  Wicked: The Life and Times of the Wicked Witch...  3.483041
# 6  0316769487                             The Catcher in the Rye  3.086998
# 7  0440222656                                The Horse Whisperer  2.994207
# 8  0515131229  Dance upon the Air (Three Sisters Island Trilogy)  2.963652
# 9  0316284955       White Oleander : A Novel (Oprah's Book Club)  2.868035
#
#    userId                                          Book Read  Rated
# 0   35859                                     Fahrenheit 451     10
# 1   35859  Harry Potter and the Sorcerer's Stone (Harry P...     10
# 2   35859  One for the Money (Stephanie Plum Novels (Pape...     10
# 3   35859                The Red Tent (Bestselling Backlist)     10
# 4   35859                                 Bel Canto: A Novel      9
# 5   35859                            The Secret Life of Bees      9
# 6   35859  Left Behind: A Novel of the Earth's Last Days ...      9
# 7   35859                                  The Joy Luck Club      8
# 8   35859                                  Two for the Dough      8
# 9   35859  Balzac and the Little Chinese Seamstress : A N...      8

# %%
index_val = 912
# get user id
userId = df.index[index_val]
books = []
ratings = []
titles = []

for isbn in df.iloc[index_val][df.iloc[index_val].isna()].index:
    books.append(isbn)
    title = data[data['ISBN']==isbn]['Book-Title'].values[0]
    titles.append(title)
    ratings.append(svd.predict(userId, isbn).est)

prediction = pd.DataFrame({'ISBN':books, 'title':titles, 'rating':ratings, 'userId':userId})  
prediction = prediction.sort_values('rating', ascending=False).iloc[:10].reset_index(drop=True)

# get other high rated books by user
temp = data[data['User-ID']==df.index[index_val]].sort_values(
    'Book-Rating', ascending=False)[['Book-Rating', 'Book-Title', 'User-ID']].iloc[:10].reset_index(drop=True)
prediction['Book Read'] = temp['Book-Title']
prediction['Rated']= temp['Book-Rating']
prediction
# Out:
#          ISBN                                              title     rating  \
# 0  0446310786                              To Kill a Mockingbird  10.000000
# 1  0671003755  She's Come Undone (Oprah's Book Club (Paperback))   8.695253
# 2  0316284955       White Oleander : A Novel (Oprah's Book Club)   8.079633
# 3  043935806X  Harry Potter and the Order of the Phoenix (Boo...   7.495306
# 4  0805063897   Nickel and Dimed: On (Not) Getting By in America   6.159421
# 5  0060938455  Fast Food Nation: The Dark Side of the All-Ame...   6.050249
# 6  059035342X  Harry Potter and the Sorcerer's Stone (Harry P...   5.918016
# 7  0375700757                            Cold Mountain : A Novel   5.902377
# 8  0345339681  The Hobbit : The Enchanting Prelude to The Lor...   5.806213
# 9  0380731851                                       Mystic River   5.725593
#
#    userId                                          Book Read  Rated
# 0   16795  A Child Called \It\": One Child's Courage to S...     10
# 1   16795                                  The Da Vinci Code     10
# 2   16795                          The Lovely Bones: A Novel     10
# 3   16795                            The Secret Life of Bees     10
# 4   16795              She's Come Undone (Oprah's Book Club)     10
# 5   16795                                       The Notebook     10
# 6   16795                              House of Sand and Fog      9
# 7   16795                The Red Tent (Bestselling Backlist)      9
# 8   16795                                The Horse Whisperer      9
# 9   16795                      The Bridges of Madison County      9

# %% [markdown]
# ## 2. Using mean of other user' weighted ratings based on similarity matrix
# Here assumed rating may not make much sense as most of the books are not read by other users

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
# replace NaN with user based average rating in pivot dataframe
df_imputed = df.fillna(df.mean(axis=0))

# get similarity between all users
similarity_matrix = cosine_similarity(df_imputed.values)

# %%
def get_recommendation(user_index):
    idx = user_index
    sim_scores = list(enumerate(similarity_matrix[idx]))

    # get books that are unrated by the given user
    unrated_books = df.iloc[idx][df.iloc[idx].isna()].index

    # get weighted ratings of unrated books by all other users
    book_ratings = (df[unrated_books].T * similarity_matrix[idx]).T

    # get top 100 similar users by skipping the current user
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)[1:101]

    # get mean of book ratings by top 100 most similar users for the unrated books
    book_ratings = book_ratings.iloc[[x[0] for x in sim_scores]].mean()
    
    # get rid of null values and sort it based on ratings
    book_ratings = book_ratings.reset_index().dropna().sort_values(0, ascending=False).iloc[:10]
    
    # get recommended book titles in sorted order
    recommended_books = data[data['ISBN'].isin(book_ratings['ISBN'])][['ISBN', 'Book-Title']]
    recommended_books = recommended_books.drop_duplicates('ISBN').reset_index(drop=True)
    assumed_ratings = book_ratings[0].reset_index(drop=True)

    return pd.DataFrame({'ISBN':recommended_books['ISBN'], 
                         'Recommended Book':recommended_books['Book-Title'], 
                         'Assumed Rating':assumed_ratings})

# %%
user_index = 2131
recommended_books = get_recommendation(user_index)
# get other high rated books by user
temp = data[data['User-ID']==df.index[user_index]].sort_values(
    'Book-Rating', ascending=False)[['Book-Rating', 'Book-Title', 'User-ID']].iloc[:10].reset_index(drop=True)
recommended_books['userId'] = temp['User-ID']
recommended_books['Book Read'] = temp['Book-Title']
recommended_books['Rated']= temp['Book-Rating']
recommended_books
# Out:
#          ISBN                                   Recommended Book  \
# 0  0684872153                    Angela's Ashes (MMP) : A Memoir
# 1  0316284955       White Oleander : A Novel (Oprah's Book Club)
# 2  0345339681  The Hobbit : The Enchanting Prelude to The Lor...
# 3  0345361792                            A Prayer for Owen Meany
# 4  0786868716                 The Five People You Meet in Heaven
# 5  080410526X                          All I Really Need to Know
# 6  0440222656                                The Horse Whisperer
# 7  0316769487                             The Catcher in the Rye
# 8  0345339703  The Fellowship of the Ring (The Lord of the Ri...
# 9  0060959037                           Prodigal Summer: A Novel
#
#    Assumed Rating  userId                                          Book Read  \
# 0        7.089074   35859                                     Fahrenheit 451
# 1        6.819865   35859  Harry Potter and the Sorcerer's Stone (Harry P...
# 2        6.214522   35859  One for the Money (Stephanie Plum Novels (Pape...
# 3        6.166465   35859                The Red Tent (Bestselling Backlist)
# 4        6.130962   35859                                 Bel Canto: A Novel
# 5        5.704645   35859                            The Secret Life of Bees
# 6        5.626918   35859  Left Behind: A Novel of the Earth's Last Days ...
# 7        4.815939   35859                                  The Joy Luck Club
# 8        4.115793   35859                                  Two for the Dough
# 9        4.087308   35859  Balzac and the Little Chinese Seamstress : A N...
#
#    Rated
# 0     10
# 1     10
# 2     10
# 3     10
# 4      9
# 5      9
# 6      9
# 7      8
# 8      8
# 9      8

# %%
user_index = 6349
recommended_books = get_recommendation(user_index)
# get other high rated books by user
temp = data[data['User-ID']==df.index[user_index]].sort_values(
    'Book-Rating', ascending=False)[['Book-Rating', 'Book-Title', 'User-ID']].iloc[:10].reset_index(drop=True)
recommended_books['userId'] = temp['User-ID']
recommended_books['Book Read'] = temp['Book-Title']
recommended_books['Rated']= temp['Book-Rating']
recommended_books
# Out:
#          ISBN                                   Recommended Book  \
# 0  0671510053                                      SHIPPING NEWS
# 1  1558743669  A Child Called \It\": One Child's Courage to S...
# 2  0060930535                      The Poisonwood Bible: A Novel
# 3  0345339681  The Hobbit : The Enchanting Prelude to The Lor...
# 4  0446672211  Where the Heart Is (Oprah's Book Club (Paperba...
# 5  0345378490                                              Congo
# 6  0375727345                              House of Sand and Fog
# 7  0345339703  The Fellowship of the Ring (The Lord of the Ri...
# 8  0060959037                           Prodigal Summer: A Novel
# 9  0375700757                            Cold Mountain : A Novel
#
#    Assumed Rating  userId                                          Book Read  \
# 0        7.467531  106225                          Girl with a Pearl Earring
# 1        7.000075  106225                    Angela's Ashes (MMP) : A Memoir
# 2        6.980253  106225  Tuesdays with Morrie: An Old Man, a Young Man,...
# 3        6.980253  106225                                    A Painted House
# 4        6.980202  106225                          The Lovely Bones: A Novel
# 5        6.967019  106225                                        Good in Bed
# 6        6.927949  106225       White Oleander : A Novel (Oprah's Book Club)
# 7        6.609094  106225                            The Secret Life of Bees
# 8        6.382191  106225                                       The Brethren
# 9        6.223824  106225                                The Handmaid's Tale
#
#    Rated
# 0     10
# 1      9
# 2      9
# 3      9
# 4      8
# 5      8
# 6      8
# 7      8
# 8      6
# 9      0
